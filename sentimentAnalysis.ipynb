# %%
#referência
# https://github.com/llSourcell/twitter_sentiment_challenge

import tweepy
from textblob import TextBlob
import pandas as pd
import numpy as np
import csv

# %%
# Step 1 - Authenticate
consumer_key= 'HS80eyaFqpCRVoRPM9XamL3Z0'
consumer_secret= 'pA7ZZ2dqJ7km7W1n2fv8jhM6pZUjiGJRDvv4SJtBkvzso6Yqi2'

access_token='80844534-9Lc223LdtkvdLHT22z73C9rIf60N21WdwczHU2TFB'
access_token_secret='bOjGH3j9ZwNk7GYqltzZo6pGCY2PycjPo8X9ojY5IJVe1'

# %%
#step 2 authenticating
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
#Step 3 - Retrieve Tweets
public_tweets = api.search('#trump')



#CHALLENGE - Instead of printing out each tweet, save each Tweet to a CSV file
#and label each one as either 'positive' or 'negative', depending on the sentiment 
#You can decide the sentiment polarity threshold yourself


for tweet in public_tweets:
    print(tweet.text)
    #print(public_tweets)
    #Step 4 Perform Sentiment Analysis on Tweets
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
    
    
    )
    

print("")
# Out:
#   File "<ipython-input-31-cc6c8e0ab735>", line 19
#     )
#     ^
# SyntaxError: invalid syntax

# %%
listaTweets =  tweet.text

df = pd.DataFrame([
    [tweet.id,
    tweet.text, TextBlob(tweet.text).sentiment,
    tweet.metadata['iso_language_code']
    ] for tweet in public_tweets],
    columns = ['ID','Tweet', 'Sentimento','Linguagem'])

# %%
df
# Out:
#                     ID                                              Tweet  \
# 0   971082697534734337  RT @FMoniteau: #dividedstates #TheResistance #...
# 1   971082657508491264  @CieraDebell #WakeUpAmerica  #TRUMP &amp; #REP...
# 2   971082631579340800  RT @fancyjam59: #ReleaseTheVideo #HRCVideo #Sh...
# 3   971082629591085056  RT @kwilli1046: Attention All #Trump Supporter...
# 4   971082626265178119  Our Modern Belief That Tyrants Can't Be Succes...
# 5   971082604211564544  RT @crazylary51: #ElectionDay  #WakeUpAmerica ...
# 6   971082601229377538  @arielpalacios Cães raivosos tem dos dois lado...
# 7   971082596565372928  @kylegriffin1 @kharyp Here's the White House r...
# 8   971082596519038976  RT @RealAlexJones: .@TedNugent talks about his...
# 9   971082584443752448  #Trump veut surtaxer l'acier qui arrive aux Et...
# 10  971082583168733184  Please watch, subscribe, follow @HAGOODMANAUTH...
# 11  971082578236080128  Federal judge in Maryland rules #Trump had the...
# 12  971082572884250625  RT @jnj_kahl: #Oscars2018 #Oscars #Trump #Whit...
#
#                                    Sentimento Linguagem
# 0                                 (0.25, 1.0)        en
# 1                                  (0.0, 0.4)        en
# 2                                  (0.0, 0.0)       und
# 3                              (0.5125, 0.65)        en
# 4                              (0.475, 0.625)        en
# 5                                  (0.0, 0.4)        en
# 6                                  (0.0, 0.0)        pt
# 7                                  (0.0, 0.0)        en
# 8                                  (0.0, 0.0)        en
# 9                                  (0.0, 0.0)        fr
# 10                                 (0.0, 0.0)        en
# 11  (0.5428571428571429, 0.46785714285714286)        en
# 12  (0.12500000000000003, 0.5888888888888889)        en

# %%
creatingCsv =pd.DataFrame.to_csv(df,sep=',',  header=True, index=True, 
                            mode='w', path_or_buf='tweepy_textblob_sentiments_analysis.csv')
